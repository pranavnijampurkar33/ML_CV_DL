# %% [markdown]
# # Titanic - Machine Learning from Disaster
# https://www.kaggle.com/c/titanic/overview

# %%
# basic library
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# visulization library
import matplotlib.pyplot as plt
import seaborn as sns

# deep learning library
import tensorflow as tf
from tensorflow import keras

# preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder
# Out:
# INFO:tensorflow:Enabling eager execution
# INFO:tensorflow:Enabling v2 tensorshape
# INFO:tensorflow:Enabling resource variables
# INFO:tensorflow:Enabling tensor equality
# INFO:tensorflow:Enabling control flow v2

# %%
train_df = pd.read_csv('./train.csv')
test_df = pd.read_csv('./test.csv')
sample_submission = pd.read_csv('./gender_submission.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Useless columns

# %%
# Get rid of columns that are not useful
train = train_df.drop(columns= ['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
test = test_df.drop(columns= ['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)

# %%
train.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ## Check distribution of Age Box plot over Survived data

# %%
sns.boxplot(x="Survived", y="Age", data=train_df)
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
train['Age'] = train['Age'].fillna(train['Age'].mean())
test['Age'] = test['Age'].fillna(test['Age'].mean())

# %%
sns.countplot(x='Embarked', data=train)
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
train['Embarked'] = train['Embarked'].fillna('C')

# %%
## Splitting Features and Labels

# %% [markdown]
# ### Seperate the features and Labels

# %%
# store feature matrix in "X"
X_train = train.iloc[:, 1:]   

# store response vector in "y"
y_train = train.iloc[:,0]    

print(X_train.shape)
print(y_train.shape)
# Out:
# (891, 7)
# (891,)

# %%
X_train.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %%
y_train.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
## Preprocess the PClass column 
def preprocess_pclass_cols(df):
    #converting integer classes to Letters and prepare for One Hot Encoding
    df['Pclass'] = df['Pclass'].map({1: 'AC', 2: 'BC', 3 : 'CC'})
    return df

# %%
X_train = preprocess_pclass_cols(X_train)
X_test = preprocess_pclass_cols(test)

# %% [markdown]
# ## One hot Encoding of Col: Sex, Embarked.
# Check with One hot encoding on PClass also

# %%
X_train = pd.get_dummies(X_train)
X_test = pd.get_dummies(test)

# %%
X_train.head()
# Out:
#     Age  SibSp  Parch     Fare  Pclass_AC  Pclass_BC  Pclass_CC  Sex_female  \
# 0  22.0      1      0   7.2500          0          0          1           0
# 1  38.0      1      0  71.2833          1          0          0           1
# 2  26.0      0      0   7.9250          0          0          1           1
# 3  35.0      1      0  53.1000          1          0          0           1
# 4  35.0      0      0   8.0500          0          0          1           0
#
#    Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 0         1           0           0           1
# 1         0           1           0           0
# 2         0           0           0           1
# 3         0           0           0           1
# 4         1           0           0           1

# %% [markdown]
# ## Preprocssing the data
# * Scalar Transformation

# %%
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train[0]
# Out:
# array([-0.5924806 ,  0.43279337, -0.47367361, -0.50244517, -0.56568542,
#        -0.51015154,  0.90258736, -0.73769513,  0.73769513, -0.48557557,
#        -0.30756234,  0.61930636])

# %% [markdown]
# ## Model Creation

# %%
model = keras.models.Sequential()

model.add(keras.layers.Dense(12, input_shape=X_train.shape[1:], kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))

# 1st hidden layer
model.add(keras.layers.Dense(200, kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.BatchNormalization())

# 2nd hidden layer
model.add(keras.layers.Dense(200, kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.BatchNormalization())

# 3rd hidden layer
model.add(keras.layers.Dense(200, kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.BatchNormalization())

# 4th hidden layer
model.add(keras.layers.Dense(200, kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.BatchNormalization())

# 5th hidden layer
model.add(keras.layers.Dense(200, kernel_initializer='he_normal'))
model.add(keras.layers.Activation('elu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.BatchNormalization())

# output layer
model.add(keras.layers.Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 12)                156
# _________________________________________________________________
# activation_6 (Activation)    (None, 12)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 200)               2600
# _________________________________________________________________
# activation_7 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 200)               800
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               40200
# _________________________________________________________________
# activation_8 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 200)               800
# _________________________________________________________________
# dense_10 (Dense)             (None, 200)               40200
# _________________________________________________________________
# activation_9 (Activation)    (None, 200)               0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 200)               800
# _________________________________________________________________
# dense_11 (Dense)             (None, 200)               40200
# _________________________________________________________________
# activation_10 (Activation)   (None, 200)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 200)               800
# _________________________________________________________________
# dense_12 (Dense)             (None, 200)               40200
# _________________________________________________________________
# activation_11 (Activation)   (None, 200)               0
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 200)               0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 200)               800
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 201
# =================================================================
# Total params: 167,757
# Trainable params: 165,757
# Non-trainable params: 2,000
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 2s 3ms/step - loss: 0.7567 - accuracy: 0.5717
# Epoch 2/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6721 - accuracy: 0.6676
# Epoch 3/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6420 - accuracy: 0.6861
# Epoch 4/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5903 - accuracy: 0.7272
# Epoch 5/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5715 - accuracy: 0.7237
# Epoch 6/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.6136 - accuracy: 0.7252
# Epoch 7/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5782 - accuracy: 0.7223
# Epoch 8/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.5407 - accuracy: 0.7681
# Epoch 9/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5229 - accuracy: 0.7766
# Epoch 10/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5656 - accuracy: 0.7419
# Epoch 11/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5589 - accuracy: 0.7573
# Epoch 12/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5363 - accuracy: 0.7773
# Epoch 13/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5075 - accuracy: 0.7674
# Epoch 14/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7747
# Epoch 15/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5490 - accuracy: 0.7483
# Epoch 16/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4907 - accuracy: 0.7819
# Epoch 17/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5596 - accuracy: 0.7621
# Epoch 18/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5175 - accuracy: 0.7788
# Epoch 19/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.7951
# Epoch 20/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4910 - accuracy: 0.7618
# Epoch 21/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.5296 - accuracy: 0.7469
# Epoch 22/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4601 - accuracy: 0.8065
# Epoch 23/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4574 - accuracy: 0.8033
# Epoch 24/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4640 - accuracy: 0.7979
# Epoch 25/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4753 - accuracy: 0.7996
# Epoch 26/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4372 - accuracy: 0.8184
# Epoch 27/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4936 - accuracy: 0.7800
# Epoch 28/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.5273 - accuracy: 0.7652
# Epoch 29/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4730 - accuracy: 0.7778
# Epoch 30/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4613 - accuracy: 0.7926
# Epoch 31/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4711 - accuracy: 0.7731
# Epoch 32/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4818 - accuracy: 0.7770
# Epoch 33/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4905 - accuracy: 0.7746
# Epoch 34/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4362 - accuracy: 0.8095
# Epoch 35/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4787 - accuracy: 0.7922
# Epoch 36/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4401 - accuracy: 0.8124
# Epoch 37/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4371 - accuracy: 0.8089
# Epoch 38/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4270 - accuracy: 0.8126
# Epoch 39/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8431
# Epoch 40/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.7928
# Epoch 41/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.8018
# Epoch 42/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4088 - accuracy: 0.8334
# Epoch 43/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4125 - accuracy: 0.8335
# Epoch 44/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4727 - accuracy: 0.7773
# Epoch 45/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4735 - accuracy: 0.7901
# Epoch 46/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4456 - accuracy: 0.7999
# Epoch 47/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4328 - accuracy: 0.8122
# Epoch 48/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4402 - accuracy: 0.7911
# Epoch 49/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4362 - accuracy: 0.8204
# Epoch 50/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4416 - accuracy: 0.8103
# Epoch 51/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4294 - accuracy: 0.8258
# Epoch 52/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4521 - accuracy: 0.8061
# Epoch 53/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4439 - accuracy: 0.8065
# Epoch 54/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4483 - accuracy: 0.8161
# Epoch 55/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4282 - accuracy: 0.8136
# Epoch 56/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8192
# Epoch 57/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4210 - accuracy: 0.8162
# Epoch 58/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4555 - accuracy: 0.7867
# Epoch 59/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4410 - accuracy: 0.8116
# Epoch 60/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4676 - accuracy: 0.8008
# Epoch 61/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3925 - accuracy: 0.8360
# Epoch 62/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4132 - accuracy: 0.8236
# Epoch 63/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.8000
# Epoch 64/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4526 - accuracy: 0.8030
# Epoch 65/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4086 - accuracy: 0.8257
# Epoch 66/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4413 - accuracy: 0.8101
# Epoch 67/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8196
# Epoch 68/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4119 - accuracy: 0.8414
# Epoch 69/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4408 - accuracy: 0.8215
# Epoch 70/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4202 - accuracy: 0.8077: 0s - loss: 0.4203 - accuracy: 0.80
# Epoch 71/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8290
# Epoch 72/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4231 - accuracy: 0.8316
# Epoch 73/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.8130
# Epoch 74/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4385 - accuracy: 0.8096
# Epoch 75/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.8145
# Epoch 76/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4057 - accuracy: 0.8387
# Epoch 77/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4216 - accuracy: 0.8220
# Epoch 78/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8315
# Epoch 79/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4209 - accuracy: 0.8201
# Epoch 80/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4094 - accuracy: 0.8254
# Epoch 81/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4025 - accuracy: 0.8498
# Epoch 82/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4029 - accuracy: 0.8354
# Epoch 83/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4670 - accuracy: 0.7984
# Epoch 84/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4541 - accuracy: 0.8006
# Epoch 85/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4019 - accuracy: 0.8315
# Epoch 86/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4280 - accuracy: 0.8156
# Epoch 87/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4108 - accuracy: 0.8217
# Epoch 88/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3909 - accuracy: 0.8458
# Epoch 89/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4004 - accuracy: 0.8400
# Epoch 90/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3923 - accuracy: 0.8345
# Epoch 91/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3829 - accuracy: 0.8530
# Epoch 92/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4311 - accuracy: 0.8153
# Epoch 93/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4217 - accuracy: 0.8204
# Epoch 94/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4126 - accuracy: 0.8505
# Epoch 95/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4126 - accuracy: 0.8092
# Epoch 96/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.3890 - accuracy: 0.8364
# Epoch 97/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4452 - accuracy: 0.8181
# Epoch 98/100
# 28/28 [==============================] - 0s 4ms/step - loss: 0.4090 - accuracy: 0.8262
# Epoch 99/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4133 - accuracy: 0.8431
# Epoch 100/100
# 28/28 [==============================] - 0s 3ms/step - loss: 0.4035 - accuracy: 0.8304

# %%
y_pred = model.predict(X_test)

# %%
y_pred = y_pred.round().astype(int)
sample_submission['Survived'] = y_pred
sample_submission.to_csv('out.csv',index=False)
